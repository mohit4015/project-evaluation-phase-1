# %% [markdown]
# Project Description:
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# Input features-No.of wins,Runs scored , At bat ,Hit,Doubles,Triples,Home runs,Base on balls, Strike out,Stole Base,Run average,Earned run,Earned run average,complete game
# , Shutout,Save, Error
#
# -- Output: Number of predicted wins (W)
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics
# For downloading the dataset, use the link given below.
#
# Dataset Link-
# •	https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/baseball.csv

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# run all necessary libraries & download dataset from github Id and execute

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.rename(columns={'W' : 'No. of wins', 'R' : 'Runs scored', 'AB' : 'At bat', 'H' : 'Hit', '2B' : 'Doubles', '3B' : 'Triples',
                   'HR' : 'Home runs', 'BB' : 'Base on balls', 'SO' : 'Strike out', 'SB' : 'Stolen base','RA' : 'Runs average', 
                  'ER' : 'Earned run', 'ERA' : 'Earned Run average', 'CG' : 'Complete game','SHO' : 'Shut Out', 'SV' : 'Save', 
                   'E' : 'Errors'},  inplace=True)

# %%
df
# Out:
#     No. of wins  Runs scored  At bat   Hit  Doubles  Triples  Home runs  \
# 0            95          724    5575  1497      300       42        139
# 1            83          696    5467  1349      277       44        156
# 2            81          669    5439  1395      303       29        141
# 3            76          622    5533  1381      260       27        136
# 4            74          689    5605  1515      289       49        151
# 5            93          891    5509  1480      308       17        232
# 6            87          764    5567  1397      272       19        212
# 7            81          713    5485  1370      246       20        217
# 8            80          644    5485  1383      278       32        167
# 9            78          748    5640  1495      294       33        161
# 10           88          751    5511  1419      279       32        172
# 11           86          729    5459  1363      278       26        230
# ...

# %% [markdown]
# (Inplace= true) is used because updata columns names is same dataframe , now we can identify the columns easily.

# %%
df.head()
# Out:
#    No. of wins  Runs scored  At bat   Hit  Doubles  Triples  Home runs  \
# 0           95          724    5575  1497      300       42        139
# 1           83          696    5467  1349      277       44        156
# 2           81          669    5439  1395      303       29        141
# 3           76          622    5533  1381      260       27        136
# 4           74          689    5605  1515      289       49        151
#
#    Base on balls  Strike out  Stolen base  Runs average  Earned run  \
# 0            383         973          104           641         601
# 1            439        1264           70           700         653
# 2            533        1157           86           640         584
# 3            404        1231           68           701         643
# 4            455        1259           83           803         746
#
#    Earned Run average  Complete game  Shut Out  Save  Errors
# 0                3.73              2         8    56      88
# ...

# %%
df.tail()
# Out:
#     No. of wins  Runs scored  At bat   Hit  Doubles  Triples  Home runs  \
# 25           92          667    5385  1346      263       26        187
# 26           84          696    5565  1486      288       39        136
# 27           79          720    5649  1494      289       48        154
# 28           74          650    5457  1324      260       36        148
# 29           68          737    5572  1479      274       49        186
#
#     Base on balls  Strike out  Stolen base  Runs average  Earned run  \
# 25            563        1258           59           595         553
# 26            457        1159           93           627         597
# 27            490        1312          132           713         659
# 28            426        1327           82           731         655
# 29            388        1283           97           844         799
#
#     Earned Run average  Complete game  Shut Out  Save  Errors
# ...

# %%
df.dtypes
# Out:
# No. of wins             int64
# Runs scored             int64
# At bat                  int64
# Hit                     int64
# Doubles                 int64
# Triples                 int64
# Home runs               int64
# Base on balls           int64
# Strike out              int64
# Stolen base             int64
# Runs average            int64
# Earned run              int64
# Earned Run average    float64
# Complete game           int64
# Shut Out                int64
# Save                    int64
# Errors                  int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   No. of wins         30 non-null     int64
#  1   Runs scored         30 non-null     int64
#  2   At bat              30 non-null     int64
#  3   Hit                 30 non-null     int64
#  4   Doubles             30 non-null     int64
#  5   Triples             30 non-null     int64
#  6   Home runs           30 non-null     int64
#  7   Base on balls       30 non-null     int64
#  8   Strike out          30 non-null     int64
#  9   Stolen base         30 non-null     int64
#  10  Runs average        30 non-null     int64
#  11  Earned run          30 non-null     int64
#  12  Earned Run average  30 non-null     float64
#  13  Complete game       30 non-null     int64
#  14  Shut Out            30 non-null     int64
#  15  Save                30 non-null     int64
# ...

# %%
df.isnull().sum()
# Out:
# No. of wins           0
# Runs scored           0
# At bat                0
# Hit                   0
# Doubles               0
# Triples               0
# Home runs             0
# Base on balls         0
# Strike out            0
# Stolen base           0
# Runs average          0
# Earned run            0
# Earned Run average    0
# Complete game         0
# Shut Out              0
# Save                  0
# Errors                0
# dtype: int64

# %% [markdown]
# no null values are present

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.nunique()
# Out:
# No. of wins           24
# Runs scored           28
# At bat                29
# Hit                   29
# Doubles               22
# Triples               23
# Home runs             27
# Base on balls         29
# Strike out            29
# Stolen base           27
# Runs average          30
# Earned run            30
# Earned Run average    30
# Complete game          9
# Shut Out              12
# Save                  20
# Errors                21
# dtype: int64

# %%
count = df.nunique()

plt.figure(figsize=(12,10))
count.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# now we can say data is equally distributed

# %%
sns.countplot(df["No. of wins"])
plt.title("No. of wins")
# Out:
# Text(0.5, 1.0, 'No. of wins')

# %%
sns.lmplot(x="Runs scored", y="No. of wins", data=df)

# %%
sns.lmplot(x="At bat", y="No. of wins", data=df)

# %%
sns.lmplot(x="Hit", y="No. of wins",data=df)

# %%
sns.lmplot(x="Doubles", y="No. of wins", data =df)

# %%
sns.lmplot(x="Triples", y= "No. of wins", data=df)

# %%
sns.lmplot(x="Home runs", y="No. of wins", data=df)

# %%
sns.lmplot(x="Base on balls", y="No. of wins", data=df)

# %%
sns.lmplot(x="Strike out", y="No. of wins", data=df)

# %%
sns.lmplot(x="Stolen base",y="No. of wins", data=df)

# %%
sns.lmplot(x="Runs average", y="No. of wins", data=df)

# %%
sns.lmplot(x="Earned run",y="No. of wins", data=df)

# %%
sns.lmplot(x="Earned Run average", y="No. of wins", data=df)

# %%
sns.lmplot(x="Complete game", y="No. of wins", data=df)

# %%
sns.lmplot(x="Shut Out", y="No. of wins", data=df)

# %%
sns.lmplot(x="Save",y="No. of wins",data=df)

# %%
sns.lmplot(x="Errors",y="No. of wins",data=df)

# %%
sns.pairplot(df)

# %%
index = 0
features = df.drop("No. of wins", axis=1)
for col, value in features.items():
    sns.relplot(x=col, y="No. of wins", kind="line", data=df)
    index += 1
plt.show()

# %% [markdown]
# # Descriptive statistics

# %%
df.describe()
# Out:
#        No. of wins  Runs scored       At bat          Hit     Doubles  \
# count    30.000000    30.000000    30.000000    30.000000   30.000000
# mean     80.966667   688.233333  5516.266667  1403.533333  274.733333
# std      10.453455    58.761754    70.467372    57.140923   18.095405
# min      63.000000   573.000000  5385.000000  1324.000000  236.000000
# 25%      74.000000   651.250000  5464.000000  1363.000000  262.250000
# 50%      81.000000   689.000000  5510.000000  1382.500000  275.500000
# 75%      87.750000   718.250000  5570.000000  1451.500000  288.750000
# max     100.000000   891.000000  5649.000000  1515.000000  308.000000
#
#          Triples   Home runs  Base on balls  Strike out  Stolen base  \
# count  30.000000   30.000000      30.000000    30.00000    30.000000
# mean   31.300000  163.633333     469.100000  1248.20000    83.500000
# std    10.452355   31.823309      57.053725   103.75947    22.815225
# ...

# %% [markdown]
# In errors columns the gap between the values is high, so outliers are present

# %%
# Check correlation of all columns

df.corr()
# Out:
#                     No. of wins  Runs scored    At bat       Hit   Doubles  \
# No. of wins            1.000000     0.430751 -0.087947  0.037612  0.427797
# Runs scored            0.430751     1.000000  0.319464  0.482856  0.560084
# At bat                -0.087947     0.319464  1.000000  0.739122  0.453370
# Hit                    0.037612     0.482856  0.739122  1.000000  0.566847
# Doubles                0.427797     0.560084  0.453370  0.566847  1.000000
# Triples               -0.251118    -0.070072  0.435422  0.478694  0.220490
# Home runs              0.307407     0.671283 -0.066983 -0.090855  0.056292
# Base on balls          0.484342     0.402452 -0.136414 -0.118281  0.302700
# Strike out             0.111850    -0.054726 -0.106022 -0.398830 -0.150752
# Stolen base           -0.157234     0.081367  0.372618  0.413444  0.195027
# Runs average          -0.812952    -0.041623  0.316010  0.224324 -0.218160
# ...

# %%
plt.figure(figsize=(18,12))
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# In this graph can see Runs average,Earned run & Earned run average are highly negative correlated and Base on balls,Doubles are highly positive correlated

# %% [markdown]
# # Finding Outliers

# %%
plt.figure(figsize=(26,30))

graph=1

for i in df:
    if graph<=17:
        plt.subplot(5,4,graph)
        sns.boxplot(data=df[i])
        plt.xlabel(i)
    graph+=1    
    
plt.show()

# %% [markdown]
# Outliers are present in featues like Errors,shut out, save,Earned run average , so

# %% [markdown]
# # Remove Outliers

# %%
from scipy.stats import zscore
zscore=zscore(df)
zabs=np.abs(zscore)

df_new=df[(zabs<3).all(axis=1)]

# %%
df.shape
# Out:
# (30, 17)

# %%
df_new.shape
# Out:
# (29, 17)

# %% [markdown]
# # Check Skewness Of data

# %%
df_new.skew()
# Out:
# No. of wins           0.119013
# Runs scored          -0.215364
# At bat                0.169573
# Hit                   0.783772
# Doubles              -0.335304
# Triples               0.090124
# Home runs             0.450862
# Base on balls         0.151193
# Strike out           -0.233815
# Stolen base           0.494966
# Runs average          0.018155
# Earned run            0.018461
# Earned Run average    0.016693
# Complete game         0.854980
# Shut Out              0.526943
# Save                  0.627480
# Errors                0.840271
# dtype: float64

# %%
plt.figure(figsize=(20,25),facecolor="white")

plot=1

for i in df_new:
    if plot<=17:
        plt.subplot(5,4,plot)
        sns.distplot(df_new[i])
        plt.xlabel(i)
    plot+=1    
    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_new.drop('Complete game',axis=1, inplace=True)
df_new.drop('Hit',axis = 1, inplace=True)
df_new.head()
# Out:
#    No. of wins  Runs scored  At bat  Doubles  Triples  Home runs  \
# 0           95          724    5575      300       42        139
# 1           83          696    5467      277       44        156
# 2           81          669    5439      303       29        141
# 3           76          622    5533      260       27        136
# 4           74          689    5605      289       49        151
#
#    Base on balls  Strike out  Stolen base  Runs average  Earned run  \
# 0            383         973          104           641         601
# 1            439        1264           70           700         653
# 2            533        1157           86           640         584
# 3            404        1231           68           701         643
# 4            455        1259           83           803         746
#
#    Earned Run average  Shut Out  Save  Errors
# 0                3.73         8    56      88
# 1                4.07        12    45      86
# ...

# %% [markdown]
# Remove columns complete game and Hit because they are very less correlation and data are skewed

# %% [markdown]
# # Skewness Removing using yeo-johnson method

# %%
skewed_features = ['Shut Out','Save','Errors']

from sklearn.preprocessing import PowerTransformer
scale = PowerTransformer(method='yeo-johnson')

# %%
df_new[skewed_features] = scale.fit_transform(df_new[skewed_features].values)
df_new[skewed_features].head()
# Out:
#    Shut Out      Save    Errors
# 0 -0.787002  1.532753 -0.348265
# 1  0.236737  0.312020 -0.540820
# 2 -0.252844 -0.664137 -1.326125
# 3 -0.513555 -0.820689  0.650818
# 4  0.236737 -1.149165 -0.540820

# %%
df_new.head()
# Out:
#    No. of wins  Runs scored  At bat  Doubles  Triples  Home runs  \
# 0           95          724    5575      300       42        139
# 1           83          696    5467      277       44        156
# 2           81          669    5439      303       29        141
# 3           76          622    5533      260       27        136
# 4           74          689    5605      289       49        151
#
#    Base on balls  Strike out  Stolen base  Runs average  Earned run  \
# 0            383         973          104           641         601
# 1            439        1264           70           700         653
# 2            533        1157           86           640         584
# 3            404        1231           68           701         643
# 4            455        1259           83           803         746
#
#    Earned Run average  Shut Out      Save    Errors
# 0                3.73 -0.787002  1.532753 -0.348265
# 1                4.07  0.236737  0.312020 -0.540820
# ...

# %%
df_new.tail()
# Out:
#     No. of wins  Runs scored  At bat  Doubles  Triples  Home runs  \
# 25           92          667    5385      263       26        187
# 26           84          696    5565      288       39        136
# 27           79          720    5649      289       48        154
# 28           74          650    5457      260       36        148
# 29           68          737    5572      274       49        186
#
#     Base on balls  Strike out  Stolen base  Runs average  Earned run  \
# 25            563        1258           59           595         553
# 26            457        1159           93           627         597
# 27            490        1312          132           713         659
# 28            426        1327           82           731         655
# 29            388        1283           97           844         799
#
#     Earned Run average  Shut Out      Save    Errors
# 25                3.44  2.090856  0.558509 -1.870191
# ...

# %%
df_new.shape
# Out:
# (29, 15)

# %%
plt.figure(figsize=(20,25),facecolor="white")

plot=1

for i in df_new:
    if plot<=15:
        plt.subplot(5,4,plot)
        sns.distplot(df_new[i])
        plt.xlabel(i)
    plot+=1    
    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#  Now the all features data are showing Bell shape curve

# %% [markdown]
# # Data Preprocessing

# %%
# Seperate features and labels
x = df_new.drop('No. of wins', axis=1)
y = df_new['No. of wins']
x.shape
# Out:
# (29, 14)

# %%
y.shape
# Out:
# (29,)

# %%
x
# Out:
#     Runs scored  At bat  Doubles  Triples  Home runs  Base on balls  \
# 0           724    5575      300       42        139            383
# 1           696    5467      277       44        156            439
# 2           669    5439      303       29        141            533
# 3           622    5533      260       27        136            404
# 4           689    5605      289       49        151            455
# 6           764    5567      272       19        212            554
# 7           713    5485      246       20        217            418
# 8           644    5485      278       32        167            436
# 9           748    5640      294       33        161            478
# 10          751    5511      279       32        172            503
# 11          729    5459      278       26        230            486
# 12          661    5417      243       21        176            435
# 13          656    5544      262       22        198            478
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: No. of wins, dtype: int64

# %% [markdown]
# # Standerdization of data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#     Runs scored    At bat   Doubles   Triples  Home runs  Base on balls  \
# 0      0.959398  0.830084  1.556538  1.010845  -0.765863      -1.536359
# 1      0.331147 -0.702831  0.201171  1.208917  -0.181389      -0.495021
# 2     -0.274666 -1.100253  1.733325 -0.276617  -0.697101       1.252941
# 3     -1.329231  0.233951 -0.800621 -0.474688  -0.869006      -1.145857
# 4      0.174084  1.255894  0.908319  1.704094  -0.353293      -0.197495
# 5      1.856900  0.716535 -0.093474 -1.266972   1.743939       1.643442
# 6      0.712585 -0.447345 -1.625627 -1.167936   1.915843      -0.885522
# 7     -0.835605 -0.447345  0.260100  0.020490   0.196801      -0.550807
# 8      1.497899  1.752672  1.202964  0.119526  -0.009484       0.230197
# 9      1.565212 -0.078310  0.319029  0.020490   0.368705       0.695081
# 10     1.071586 -0.816380  0.260100 -0.573723   2.362794       0.378960
# 11    -0.454167 -1.412514 -1.802414 -1.068901   0.506228      -0.569402
# ...

# %% [markdown]
# # Check and handle multicolinarity using VIF

# %%
df_new.columns
# Out:
# Index(['No. of wins', 'Runs scored', 'At bat', 'Doubles', 'Triples',
#        'Home runs', 'Base on balls', 'Strike out', 'Stolen base',
#        'Runs average', 'Earned run', 'Earned Run average', 'Shut Out', 'Save',
#        'Errors'],
#       dtype='object')

# %%
Columnsname=[ 'Runs scored', 'At bat', 'Doubles', 'Triples',
       'Home runs', 'Base on balls', 'Strike out', 'Stolen base',
       'Runs average', 'Earned run', 'Earned Run average', 'Shut Out', 'Save',
       'Errors']

# %%
import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_data = pd.DataFrame()
vif_data["Features List"]=Columnsname
vif_data["VIF Value"]=[variance_inflation_factor(x.values, i)
     for i in range(len(x.columns))]
vif_data
# Out:
#          Features List    VIF Value
# 0          Runs scored     6.219825
# 1               At bat     9.828077
# 2              Doubles     2.683572
# 3              Triples     3.196853
# 4            Home runs     7.369072
# 5        Base on balls     2.686472
# 6           Strike out     2.741072
# 7          Stolen base     1.757901
# 8         Runs average   179.096825
# 9           Earned run  1754.643859
# 10  Earned Run average  1310.260128
# 11            Shut Out     3.086344
# 12                Save     4.021573
# 13              Errors     1.742105

# %% [markdown]
#  In Earned run multicolinarity exist so we drop it

# %%
x.drop('Earned run',axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF values            Features
# 0     4.352902         Runs scored
# 1     3.177214              At bat
# 2     2.597985             Doubles
# 3     3.072775             Triples
# 4     4.949255           Home runs
# 5     2.561982       Base on balls
# 6     2.661842          Strike out
# 7     1.680467         Stolen base
# 8   119.939744        Runs average
# 9   111.859162  Earned Run average
# 10    2.932319            Shut Out
# 11    2.112465                Save
# 12    1.742101              Errors

# %%
x.drop('Runs average',axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF values            Features
# 0     4.250076         Runs scored
# 1     2.238746              At bat
# 2     2.597917             Doubles
# 3     3.030073             Triples
# 4     4.562014           Home runs
# 5     2.222720       Base on balls
# 6     2.042786          Strike out
# 7     1.568151         Stolen base
# 8     3.878177  Earned Run average
# 9     2.651314            Shut Out
# 10    1.954370                Save
# 11    1.493128              Errors

# %%
print(x.shape)
print(y.shape)
# Out:
# (29, 12)
# (29,)

# %% [markdown]
# # Before processing we will find best random state which gives us highest accuracy

# %%
import sklearn
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

#metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score

# %%
maxAcc = 0
maxRS = 0

for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.3, random_state=i)
    modRF = RandomForestRegressor()
    modRF.fit(x_train,y_train)
    pred = modRF.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAcc:
        maxAcc = acc
        maxRs=i
print(f"Best Accuracy is: {maxAcc} on Random State: {maxRs}")
# Out:
# Best Accuracy is: 0.8296888888888889 on Random State: 70

# %%
#Best Parameter for Lasso
parameters = {'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
lasso = Lasso()
clf = GridSearchCV(lasso,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
dt=DecisionTreeRegressor()
kn=KNeighborsRegressor()
adb=AdaBoostRegressor()
gdb=GradientBoostingRegressor()
lnr=LinearRegression()
rfr=RandomForestRegressor()
sv=SVR()
lss=Lasso(alpha=1,random_state=0)

model=[dt,kn,adb,gdb,lnr,rfr,sv,lss]

for i in model:
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.3, random_state=94)
    i.fit(x_train,y_train)
    predi=i.predict(x_test)
    print('performance matrix of',i,'is:')
    print("RMSE Score is:",mean_squared_error(y_test,predi))
    r2 = r2_score(y_test, predi)*100
    print("R2 Score is:", r2)
    cv_score = (cross_val_score(i, x, y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    result = r2 - cv_score
    print("R2 Score - Cross Validation Score is", result)
    print("*****************************************************************")
# Out:
# performance matrix of DecisionTreeRegressor() is:
# RMSE Score is: 68.0
# R2 Score is: 9.318406322028316
# Cross Validation Score: -189.28481828965417
# R2 Score - Cross Validation Score is 198.6032246116825
# *****************************************************************
# performance matrix of KNeighborsRegressor() is:
# RMSE Score is: 33.795555555555545
# R2 Score is: 54.93184063220284
# Cross Validation Score: 1.3785729869268004
# R2 Score - Cross Validation Score is 53.553267645276044
# *****************************************************************
# performance matrix of AdaBoostRegressor() is:
# RMSE Score is: 19.405214008774603
# R2 Score is: 74.12212158856202
# Cross Validation Score: -64.42917438966269
# R2 Score - Cross Validation Score is 138.55129597822472
# *****************************************************************
# performance matrix of GradientBoostingRegressor() is:
# RMSE Score is: 30.746283522711995
# R2 Score is: 58.998206036554635
# ...

# %% [markdown]
# # Saving Best model

# %%
Final_Model = LinearRegression()
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.3, random_state=94)
Classifier = Final_Model.fit(x_train, y_train)
mod_pred = Final_Model.predict(x_test)
mod_r2 = r2_score(y_test,mod_pred)*100
print("R2 score for the Best Model is:", mod_r2)
# Out:
# R2 score for the Best Model is: 61.41543885760727

# %% [markdown]
# # Saving the model

# %%
import joblib 
joblib.dump(Final_Model,'Baseball case study.pkl')
# Out:
# ['Baseball case study.pkl']

# %%
loadmodel = joblib.load('Baseball case study.pkl')

# %%
# Prediction using same model
import numpy as np
a = np.array(y_test)
predicted = np.array(loadmodel.predict(x_test))
df_final = pd.DataFrame({"Original":a,"Predicted":predicted},index=range(len(a)))
df_final
# Out:
#    Original  Predicted
# 0        98  98.242093
# 1        83  89.562815
# 2        85  83.406243
# 3        74  67.446363
# 4        84  87.112568
# 5        76  72.722402
# 6        92  89.858329
# 7        79  82.064873
# 8        68  79.720607
